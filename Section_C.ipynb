# %% [markdown]
# # **SECTION C :**

# %%
import pandas as pd

# %%
df = pd.read_csv('ev_output1.csv')
df.head()
# Out:
#    Manufacturer  Model  Year  Battery_Type  Battery_Capacity_kWh  Range_km  \
# 0             0    160  2015             7             -0.766435 -0.934785
# 1            23    136  2025             7              0.174316 -0.948542
# 2            33     33  2020             1             -0.527216 -0.790339
# 3             1    170  2025             5              0.972611 -1.443789
# 4             0    160  2023             7             -0.873950 -0.095617
#
#    Charging_Type  Charge_Time_hr  Price_USD  Color  Country_of_Manufacture  \
# 0              2        0.832215   0.594307     30                      36
# 1             14        0.324759   1.053997     53                      21
# 2              6        0.802364   0.107809      1                      36
# 3             12        1.279970  -0.432822     47                       0
# 4             10       -0.779705   1.455607     23                      38
#
# ...

# %%
# x and y define

x = df.drop(['Warranty_Years'], axis=1)
y = df['Warranty_Years']

# %%
x
# Out:
#       Manufacturer  Model  Year  Battery_Type  Battery_Capacity_kWh  Range_km  \
# 0                0    160  2015             7             -0.766435 -0.934785
# 1               23    136  2025             7              0.174316 -0.948542
# 2               33     33  2020             1             -0.527216 -0.790339
# 3                1    170  2025             5              0.972611 -1.443789
# 4                0    160  2023             7             -0.873950 -0.095617
# ...            ...    ...   ...           ...                   ...       ...
# 3017            11    139  2018            12             -0.925019 -1.154895
# 3018            28     10  2019             4              1.413420  0.172641
# 3019             4     94  2021             5              1.402669 -0.886637
# 3020            28    159  2021            11              0.324836 -0.694041
# 3021            27     98  2016             6             -0.218112  0.372116
#
# ...

# %%
y
# Out:
# 0       3
# 1       3
# 2       5
# 3       5
# 4       4
#        ..
# 3017    5
# 3018    3
# 3019    3
# 3020    3
# 3021    5
# Name: Warranty_Years, Length: 3022, dtype: int64

# %%
# train_test_split

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=42)

# %%
X_train
# Out:
#       Manufacturer  Model  Year  Battery_Type  Battery_Capacity_kWh  Range_km  \
# 2740            10     49  2025             7             -0.282620  0.771064
# 440             52    164  2020             8             -1.459903  1.176892
# 508             50     11  2022            12             -1.599672  0.014437
# 76              42    133  2022             0             -0.930395 -0.528958
# 1947            46     15  2018             6             -0.126724  0.674766
# ...            ...    ...   ...           ...                   ...       ...
# 1638            42    133  2019            10             -0.610539  0.055708
# 1095            23    136  2018             0             -1.145424  0.578468
# 1130            38    127  2022             6              0.625877  1.121864
# 1294            44     44  2019             3             -0.497649  0.454657
# 860             52    162  2016            10             -1.645366 -1.354370
#
# ...

# %%
X_test
# Out:
#       Manufacturer  Model  Year  Battery_Type  Battery_Capacity_kWh  Range_km  \
# 1413            49     71  2016            11             -0.879325  0.028194
# 612             11    138  2017             2             -0.742245 -0.632135
# 331             25     39  2019            11             -1.519036 -1.017327
# 211             31     27  2023             0              1.687582 -0.528958
# 52              24     85  2020             2             -1.363140 -1.154895
# ...            ...    ...   ...           ...                   ...       ...
# 596             22     36  2025             1             -0.193921 -1.230558
# 1641            21     61  2025             5             -1.169614 -1.491938
# 802              0    160  2016             8              1.574692 -0.006198
# 2154             7    144  2015            10              0.115183  0.956782
# 3007            31     28  2015             2              1.359663 -1.223679
#
# ...

# %%
y_train
# Out:
# 2740    5
# 440     3
# 508     3
# 76      3
# 1947    4
#        ..
# 1638    4
# 1095    5
# 1130    5
# 1294    4
# 860     3
# Name: Warranty_Years, Length: 2115, dtype: int64

# %%
y_test
# Out:
# 1413    5
# 612     3
# 331     3
# 211     4
# 52      4
#        ..
# 596     3
# 1641    3
# 802     4
# 2154    3
# 3007    4
# Name: Warranty_Years, Length: 907, dtype: int64

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(max_depth=3, n_estimators=150, min_samples_split=4,min_samples_leaf= 3, max_features=2)

rf_model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=3, max_features=2, min_samples_leaf=3,
#                       min_samples_split=4, n_estimators=150)

# %%
y_pred = rf_model.predict(X_test)

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print(f'R-squared: {r2}')
# Out:
# R-squared: 0.0004280255834014923

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_pred)
print('Mean Absolute Error:&quot :' , mae)
# Out:
# Mean Absolute Error:&quot : 0.6721030974690391

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:', mse)
# Out:
# Mean Squared Error: 0.6641933893061246

# %%
# predict on new data

row_data = [0, 160, 2015, 7, -0.766435, -0.934785, 2, 0.832215, 0.594307, 30, 36, 0.0, 5.0, 1.649538]

r = rf_model.predict([row_data])
print(r)
# Out:
# [3.95297316]
# /home/bts29/Desktop/ml_test_shiv/venv/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

lr_model = LinearRegression()

lr_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr_model.predict(X_test)

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print(f'R-squared: {r2}')
# Out:
# R-squared: -0.004589232579771174

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_pred)
print('Mean Absolute Error:&quot :' , mae)
# Out:
# Mean Absolute Error:&quot : 0.6809083891069038

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:', mse)
# Out:
# Mean Squared Error: 0.6675272459864967

# %% [markdown]
# # GradientBoosting

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr_model = GradientBoostingRegressor(n_estimators=150, alpha=1, max_depth=3, min_samples_split=4, min_samples_leaf= 3, max_features=2, random_state=42)
gbr_model = GradientBoostingRegressor()

gbr_model.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred = gbr_model.predict(X_test)

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print(f'R-squared: {r2}')
# Out:
# R-squared: -0.047530277566289136

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_pred)
print('Mean Absolute Error:&quot :' , mae)
# Out:
# Mean Absolute Error:&quot : 0.7089488273197555

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:', mse)
# Out:
# Mean Squared Error: 0.6960606172093028
